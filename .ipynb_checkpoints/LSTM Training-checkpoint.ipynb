# %%
from numpy import array
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
import tensorflow as tf
import matplotlib.pyplot as plt
import ipynb
import keras
from sklearn.metrics import mean_squared_error
import pandas as pd

# %%
#Store variables for training
# %store -r AMC_Price
# %store -r AMC_Open
# %store -r AMC_High
# %store -r AMC_Low
# %store -r AMC_Vol
# %store -r AMC_Change

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
def LSTM_Prediction_Model(): 
    data_price = AMC_Price
    data_open = AMC_Open
    data_high = AMC_High
    data_low = AMC_Low
    data_vol = AMC_Vol
    data_change = AMC_Change

    # choose a number of time steps
    n_steps = 8
    # split into samples / reshape from x,y to x,y,z
    Xprice, y = split_sequence(data_price, n_steps)
    Xprice = Xprice.reshape((Xprice.shape[0], n_steps, 1))
    
    Xopen, y = split_sequence(data_open, n_steps)
    Xopen = Xopen.reshape((Xopen.shape[0], n_steps, 1))
    
    Xhigh, y = split_sequence(data_high, n_steps)
    Xhigh = Xhigh.reshape((Xhigh.shape[0], n_steps, 1))
    
    Xlow, y = split_sequence(data_low, n_steps)
    Xlow = Xlow.reshape((Xlow.shape[0], n_steps, 1))
    
    Xvol, y = split_sequence(data_vol, n_steps)
    Xvol = Xlow.reshape((Xvol.shape[0], n_steps, 1))
    
    Xchange, y = split_sequence(data_change, n_steps)
    Xchange = Xchange.reshape((Xchange.shape[0], n_steps, 1))
    
    #concatenate training data into one array (samples, steps, features)
    Xtraining = np.concatenate((Xprice, Xopen, Xhigh, Xlow, Xchange), axis = 2)
    #reshape to fit the convolution window
    Xtrainingwide = Xtraining.reshape(Xtraining.shape[0], Xtraining.shape[1], Xtraining.shape[2], 1)

    n_filters=10
    fsize=5
    window_size=8
    n_features=5
    hour_filter = 8

    prediction_model = Sequential()
    layer1 = tf.keras.layers.Conv1D(n_filters, fsize, padding="same", activation="relu", input_shape=(window_size, n_features))
    layer2 = tf.keras.layers.Flatten()
    layer3 = tf.keras.layers.Dense(1000, activation='relu')
    layer4 = tf.keras.layers.Dense(100)
    layer5 = tf.keras.layers.Dense(1)
    prediction_model.add(layer1)
    prediction_model.add(layer2)
    prediction_model.add(layer3)
    prediction_model.add(layer4)
    prediction_model.add(layer5)
    prediction_model.compile(optimizer="adam", loss="mean_squared_error")
    prediction_model.fit(Xtraining, y, epochs=200, batch_size =32, verbose=1)
    return prediction_model

# %%
AMCModel = LSTM_Prediction_Model()
# Out:
# [[[ 8.01]
#   [ 7.63]
#   [ 7.85]
#   ...
#   [ 5.75]
#   [ 5.51]
#   [ 5.46]]
#
#  [[ 7.63]
#   [ 7.85]
#   [ 6.99]
#   ...
#   [ 5.51]
#   [ 5.46]
#   [ 5.32]]
#
#  [[ 7.85]
#   [ 6.99]
#   [ 6.01]
#   ...
#   [ 5.46]
#   [ 5.32]
#   [ 5.49]]
#
#  ...
#
#  [[19.78]
#   [19.96]
#   [19.96]
#   ...
#   [19.35]
#   [19.5 ]
#   [19.5 ]]
#
#  [[19.96]
#   [19.96]
#   [19.82]
#   ...
#   [19.5 ]
#   [19.5 ]
#   [19.4 ]]
#
#  [[19.96]
#   [19.82]
#   [19.53]
#   ...
#   [19.5 ]
#   [19.4 ]
#   [18.81]]]
# Epoch 1/200
# 57/57 [==============================] - 0s 1ms/step - loss: 117.5499
# Epoch 2/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 3/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0104
# Epoch 4/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0057
# Epoch 5/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0107
# Epoch 6/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0050
# Epoch 7/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0068
# Epoch 8/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0043
# Epoch 9/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0048
# Epoch 10/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0046
# Epoch 11/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0060
# Epoch 12/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0047
# Epoch 13/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 14/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 15/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 16/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 17/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 18/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 19/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 20/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0033
# Epoch 21/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 22/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0043
# Epoch 23/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 24/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 25/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 26/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 27/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 28/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 29/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 30/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 31/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0052
# Epoch 32/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 33/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 34/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0037
# Epoch 35/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 36/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 37/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 38/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 39/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 40/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 41/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 42/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0041
# Epoch 43/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 44/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 45/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 46/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 47/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 48/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0052
# Epoch 49/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 50/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 51/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0033
# Epoch 52/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 53/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0041
# Epoch 54/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 55/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0066
# Epoch 56/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 57/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 58/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 59/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0055
# Epoch 60/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 61/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 62/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 63/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0055
# Epoch 64/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 65/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0040
# Epoch 66/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 67/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0038
# Epoch 68/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0082
# Epoch 69/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0299
# Epoch 70/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0097
# Epoch 71/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 72/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0065
# Epoch 73/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0033
# Epoch 74/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0067
# Epoch 75/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0037
# Epoch 76/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 77/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0064
# Epoch 78/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0041
# Epoch 79/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0037
# Epoch 80/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0078
# Epoch 81/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0504
# Epoch 82/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0053
# Epoch 83/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0056
# Epoch 84/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0282
# Epoch 85/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 86/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 87/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0042
# Epoch 88/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0189
# Epoch 89/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0298
# Epoch 90/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0051
# Epoch 91/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0071
# Epoch 92/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 93/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0067
# Epoch 94/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0112
# Epoch 95/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0069
# Epoch 96/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 97/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 98/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0127
# Epoch 99/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0055
# Epoch 100/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 101/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0045
# Epoch 102/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0082
# Epoch 103/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0041
# Epoch 104/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0107
# Epoch 105/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0100
# Epoch 106/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 107/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0053
# Epoch 108/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0100
# Epoch 109/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 110/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0116
# Epoch 111/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0056
# Epoch 112/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0079
# Epoch 113/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0124
# Epoch 114/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 115/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 116/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 117/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0049
# Epoch 118/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 119/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0062
# Epoch 120/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0134
# Epoch 121/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 122/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0041
# Epoch 123/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0038
# Epoch 124/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0083
# Epoch 125/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0045
# Epoch 126/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0116
# Epoch 127/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0096
# Epoch 128/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0142
# Epoch 129/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0066
# Epoch 130/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 131/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0059
# Epoch 132/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 133/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 134/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 135/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 136/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 137/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 138/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0040
# Epoch 139/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 140/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 141/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 142/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 143/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 144/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 145/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0038
# Epoch 146/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 147/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 148/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 149/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 150/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0037
# Epoch 151/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 152/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 153/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 154/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 155/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 156/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 157/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 158/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0040
# Epoch 159/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 160/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 161/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 162/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 163/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 164/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 165/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 166/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 167/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 168/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 169/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 170/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 171/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0042
# Epoch 172/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 173/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 174/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 175/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 176/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 177/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 178/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 179/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 180/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0037
# Epoch 181/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 182/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 183/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 184/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 185/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 186/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 187/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 188/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 189/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0056
# Epoch 190/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0044
# Epoch 191/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 192/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 193/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 194/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 195/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 196/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 197/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 198/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 199/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 200/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0018
